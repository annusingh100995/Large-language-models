# %% [markdown]
# OpenAI Code

# %%
from dotenv import load_dotenv
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI

# Load environment variables from .env
load_dotenv()

# Create a ChatOpenAI model
model = ChatOpenAI(model="gpt-4o")

# SystemMessage:
#   Message for priming AI behavior, usually passed in as the first of a sequenc of input messages.
# HumanMessagse:
#   Message from a human to the AI model.
messages = [
    SystemMessage(content="Solve the following math problems"),
    HumanMessage(content="What is 81 divided by 9?"),
]

# Invoke the model with messages
result = model.invoke(messages)
print(f"Answer from AI: {result.content}")


# AIMessage:
#   Message from an AI.
messages = [
    SystemMessage(content="Solve the following math problems"),
    HumanMessage(content="What is 81 divided by 9?"),
    AIMessage(content="81 divided by 9 is 9."),
    HumanMessage(content="What is 10 times 5?"),
]

# Invoke the model with messages
result = model.invoke(messages)
print(f"Answer from AI: {result.content}")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[28], line 21
#      15 messages = [
#      16     SystemMessage(content="Solve the following math problems"),
#      17     HumanMessage(content="What is 81 divided by 9?"),
#      18 ]
#      20 # Invoke the model with messages
# ---> 21 result = model.invoke(messages)
#      22 print(f"Answer from AI: {result.content}")
#      25 # AIMessage:
#      26 #   Message from an AI.
#
# File ~\anaconda3\envs\llms\Lib\site-packages\langchain_core\language_models\chat_models.py:331, in invoke(self, input, config, stop, **kwargs)
#     325     return values
#     327 model_config = ConfigDict(
#     328     arbitrary_types_allowed=True,
#     329 )
# --> 331 @cached_property
#     332 def _serialized(self) -> dict[str, Any]:
#     333     return dumpd(self)
#     335 # --- Runnable methods ---
#
# File ~\anaconda3\envs\llms\Lib\site-packages\langchain_core\language_models\chat_models.py:894, in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     892 if exceptions:
#     893     if run_managers:
# --> 894         await asyncio.gather(
#     895             *[
#     896                 run_manager.on_llm_end(
#     897                     LLMResult(
#     898                         generations=[res.generations],  # type: ignore[list-item, union-attr]
#     899                         llm_output=res.llm_output,  # type: ignore[union-attr]
#     900                     )
#     901                 )
#     902                 for run_manager, res in zip(run_managers, results)
#     903                 if not isinstance(res, Exception)
#     904             ]
#     905         )
#     906     raise exceptions[0]
#     907 flattened_outputs = [
#     908     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item, union-attr]
#     909     for res in results
#     910 ]
#
# File ~\anaconda3\envs\llms\Lib\site-packages\langchain_core\language_models\chat_models.py:719, in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     680 def generate(
#     681     self,
#     682     messages: list[list[BaseMessage]],
#    (...)    690     **kwargs: Any,
#     691 ) -> LLMResult:
#     692     """Pass a sequence of prompts to the model and return model generations.
#     693
#     694     This method should make use of batched calls for models that expose a batched
#     695     API.
#     696
#     697     Use this method when you want to:
#     698         1. take advantage of batched calls,
#     699         2. need more output from the model than just the top generated value,
#     700         3. are building chains that are agnostic to the underlying language model
#     701             type (e.g., pure text completion models vs chat models).
#     702
#     703     Args:
#     704         messages: List of list of messages.
#     705         stop: Stop words to use when generating. Model output is cut off at the
#     706             first occurrence of any of these substrings.
#     707         callbacks: Callbacks to pass through. Used for executing additional
#     708             functionality, such as logging or streaming, throughout generation.
#     709         tags: The tags to apply.
#     710         metadata: The metadata to apply.
#     711         run_name: The name of the run.
#     712         run_id: The ID of the run.
#     713         **kwargs: Arbitrary additional keyword arguments. These are usually passed
#     714             to the model provider API call.
#     715
#     716     Returns:
#     717         An LLMResult, which contains a list of candidate Generations for each input
#     718             prompt and additional model provider-specific output.
# --> 719     """
#     720     ls_structured_output_format = kwargs.pop(
#     721         "ls_structured_output_format", None
#     722     ) or kwargs.pop("structured_output_format", None)
#     723     ls_structured_output_format_dict = _format_ls_structured_output(
#     724         ls_structured_output_format
#     725     )
#
# File ~\anaconda3\envs\llms\Lib\site-packages\langchain_core\language_models\chat_models.py:960, in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     952 def _generate_with_cache(
#     953     self,
#     954     messages: list[BaseMessage],
#    (...)    957     **kwargs: Any,
#     958 ) -> ChatResult:
#     959     llm_cache = self.cache if isinstance(self.cache, BaseCache) else get_llm_cache()
# --> 960     # We should check the cache unless it's explicitly set to False
#     961     # A None cache means we should use the default global cache
#     962     # if it's configured.
#     963     check_cache = self.cache or self.cache is None
#     964     if check_cache:
#
# File ~\anaconda3\envs\llms\Lib\site-packages\langchain_openai\chat_models\base.py:955, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     953     generation_info = {"headers": dict(raw_response.headers)}
#     954 else:
# --> 955     response = self.client.create(**payload)
#     956 return self._create_chat_result(response, generation_info)
#
# File ~\anaconda3\envs\llms\Lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\llms\Lib\site-packages\openai\resources\chat\completions\completions.py:914, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     871 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     872 def create(
#     873     self,
#    (...)    911     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     912 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     913     validate_response_format(response_format)
# --> 914     return self._post(
#     915         "/chat/completions",
#     916         body=maybe_transform(
#     917             {
#     918                 "messages": messages,
#     919                 "model": model,
#     920                 "audio": audio,
#     921                 "frequency_penalty": frequency_penalty,
#     922                 "function_call": function_call,
#     923                 "functions": functions,
#     924                 "logit_bias": logit_bias,
#     925                 "logprobs": logprobs,
#     926                 "max_completion_tokens": max_completion_tokens,
#     927                 "max_tokens": max_tokens,
#     928                 "metadata": metadata,
#     929                 "modalities": modalities,
#     930                 "n": n,
#     931                 "parallel_tool_calls": parallel_tool_calls,
#     932                 "prediction": prediction,
#     933                 "presence_penalty": presence_penalty,
#     934                 "reasoning_effort": reasoning_effort,
#     935                 "response_format": response_format,
#     936                 "seed": seed,
#     937                 "service_tier": service_tier,
#     938                 "stop": stop,
#     939                 "store": store,
#     940                 "stream": stream,
#     941                 "stream_options": stream_options,
#     942                 "temperature": temperature,
#     943                 "tool_choice": tool_choice,
#     944                 "tools": tools,
#     945                 "top_logprobs": top_logprobs,
#     946                 "top_p": top_p,
#     947                 "user": user,
#     948                 "web_search_options": web_search_options,
#     949             },
#     950             completion_create_params.CompletionCreateParams,
#     951         ),
#     952         options=make_request_options(
#     953             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     954         ),
#     955         cast_to=ChatCompletion,
#     956         stream=stream or False,
#     957         stream_cls=Stream[ChatCompletionChunk],
#     958     )
#
# File ~\anaconda3\envs\llms\Lib\site-packages\openai\_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)   1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\anaconda3\envs\llms\Lib\site-packages\openai\_base_client.py:919, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     916 else:
#     917     retries_taken = 0
# --> 919 return self._request(
#     920     cast_to=cast_to,
#     921     options=options,
#     922     stream=stream,
#     923     stream_cls=stream_cls,
#     924     retries_taken=retries_taken,
#     925 )
#
# File ~\anaconda3\envs\llms\Lib\site-packages\openai\_base_client.py:1008, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1006 if remaining_retries > 0 and self._should_retry(err.response):
#    1007     err.response.close()
# -> 1008     return self._retry_request(
#    1009         input_options,
#    1010         cast_to,
#    1011         retries_taken=retries_taken,
#    1012         response_headers=err.response.headers,
#    1013         stream=stream,
#    1014         stream_cls=stream_cls,
#    1015     )
#    1017 # If the response is streamed then we need to explicitly read the response
#    1018 # to completion before attempting to access the response text.
#    1019 if not err.response.is_closed:
#
# File ~\anaconda3\envs\llms\Lib\site-packages\openai\_base_client.py:1057, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1053 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1054 # different thread if necessary.
#    1055 time.sleep(timeout)
# -> 1057 return self._request(
#    1058     options=options,
#    1059     cast_to=cast_to,
#    1060     retries_taken=retries_taken + 1,
#    1061     stream=stream,
#    1062     stream_cls=stream_cls,
#    1063 )
#
# File ~\anaconda3\envs\llms\Lib\site-packages\openai\_base_client.py:1008, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1006 if remaining_retries > 0 and self._should_retry(err.response):
#    1007     err.response.close()
# -> 1008     return self._retry_request(
#    1009         input_options,
#    1010         cast_to,
#    1011         retries_taken=retries_taken,
#    1012         response_headers=err.response.headers,
#    1013         stream=stream,
#    1014         stream_cls=stream_cls,
#    1015     )
#    1017 # If the response is streamed then we need to explicitly read the response
#    1018 # to completion before attempting to access the response text.
#    1019 if not err.response.is_closed:
#
# File ~\anaconda3\envs\llms\Lib\site-packages\openai\_base_client.py:1057, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1053 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1054 # different thread if necessary.
#    1055 time.sleep(timeout)
# -> 1057 return self._request(
#    1058     options=options,
#    1059     cast_to=cast_to,
#    1060     retries_taken=retries_taken + 1,
#    1061     stream=stream,
#    1062     stream_cls=stream_cls,
#    1063 )
#
# File ~\anaconda3\envs\llms\Lib\site-packages\openai\_base_client.py:1023, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1020         err.response.read()
#    1022     log.debug("Re-raising status error")
# -> 1023     raise self._make_status_error_from_response(err.response) from None
#    1025 return self._process_response(
#    1026     cast_to=cast_to,
#    1027     options=options,
#    (...)   1031     retries_taken=retries_taken,
#    1032 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %% [markdown]
# Ollama Code

# %%
import ollama
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_community.chat_models import ChatOllama
from langchain_community.chat_models import ChatOpenAI, ChatGooglePalm

# %%
ollama_model_name = "llama3.2"  # Replace with the name of your Ollama model
ollama_model = ChatOllama(model=ollama_model_name)

# %%
messages = [
    SystemMessage(content="Solve the following math problems"),
    HumanMessage(content="What is 81 divided by 9?"),
]

# Invoke the model with messages
result = ollama_model.invoke(messages)
print(f"Answer from AI: {result.content}")
# Out:
# Answer from AI: 81 ÷ 9 = 9

# %%
# AIMessage:
#   Message from an AI.
messages = [
    SystemMessage(content="Solve the following math problems"),
    HumanMessage(content="What is 81 divided by 9?"),
    AIMessage(content="81 divided by 9 is 9."),
    HumanMessage(content="What is 10 times 5?"),
]

# Invoke the model with messages
result = ollama_model.invoke(messages)
print(f"Answer from AI: {result.content}")
# Out:
# Answer from AI: 10 × 5 = 50

# %%
pip install langchain-anthropic
# Out:
# Collecting langchain-anthropic
#   Downloading langchain_anthropic-0.3.11-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: anthropic<1,>=0.49.0 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langchain-anthropic) (0.49.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.52 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langchain-anthropic) (0.3.52)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langchain-anthropic) (2.11.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from anthropic<1,>=0.49.0->langchain-anthropic) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from anthropic<1,>=0.49.0->langchain-anthropic) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from anthropic<1,>=0.49.0->langchain-anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from anthropic<1,>=0.49.0->langchain-anthropic) (0.9.0)
# Requirement already satisfied: sniffio in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from anthropic<1,>=0.49.0->langchain-anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from anthropic<1,>=0.49.0->langchain-anthropic) (4.13.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-anthropic) (0.3.28)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-anthropic) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-anthropic) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-anthropic) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-anthropic) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (0.4.0)
# Requirement already satisfied: idna>=2.8 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from anyio<5,>=3.5.0->anthropic<1,>=0.49.0->langchain-anthropic) (3.10)
# Requirement already satisfied: certifi in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->anthropic<1,>=0.49.0->langchain-anthropic) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->anthropic<1,>=0.49.0->langchain-anthropic) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic<1,>=0.49.0->langchain-anthropic) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.52->langchain-anthropic) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.52->langchain-anthropic) (3.10.16)
# Requirement already satisfied: requests<3,>=2 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.52->langchain-anthropic) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.52->langchain-anthropic) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.52->langchain-anthropic) (0.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.52->langchain-anthropic) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.52->langchain-anthropic) (2.3.0)
# Downloading langchain_anthropic-0.3.11-py3-none-any.whl (25 kB)
# Installing collected packages: langchain-anthropic
# Successfully installed langchain-anthropic-0.3.11
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-google-genai
# Out:
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-2.1.3-py3-none-any.whl.metadata (4.7 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-ai-generativelanguage<0.7.0,>=0.6.16 (from langchain-google-genai)
#   Downloading google_ai_generativelanguage-0.6.17-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.52 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langchain-google-genai) (0.3.52)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langchain-google-genai) (2.11.3)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.24.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (5.29.3)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (0.3.28)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (4.13.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.4.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.69.2)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.72.0rc1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (4.9)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (0.23.0)
# Requirement already satisfied: anyio in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (4.9.0)
# Requirement already satisfied: certifi in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (1.0.7)
# Requirement already satisfied: idna in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (0.14.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\annu\anaconda3\envs\llms\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (1.3.1)
# Downloading langchain_google_genai-2.1.3-py3-none-any.whl (43 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_ai_generativelanguage-0.6.17-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 17.7 MB/s eta 0:00:00
# Installing collected packages: filetype, google-ai-generativelanguage, langchain-google-genai
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.15
#     Uninstalling google-ai-generativelanguage-0.6.15:
#       Successfully uninstalled google-ai-generativelanguage-0.6.15
# Successfully installed filetype-1.2.0 google-ai-generativelanguage-0.6.17 langchain-google-genai-2.1.3
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.4 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.6.17 which is incompatible.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_anthropic import ChatAnthropic
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from dotenv import load_dotenv

# Load environment variables from .env
load_dotenv()
# Out:
# True

# %%
messages = [
    SystemMessage(content="Solve the following math problems"),
    HumanMessage(content="What is 81 divided by 9?"),
    AIMessage(content="81 divided by 9 is 9."),
    HumanMessage(content="What is 10 times 5?"),
]

# %%
model = ChatAnthropic(model="claude-3-opus-20240229")

result = model.invoke(messages)
print(f"Answer from Anthropic: {result.content}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 model = ChatAnthropic(model="claude-3-opus-20240229")
# ----> 3 result = model.invoke(messages)
#       4 print(f"Answer from Anthropic: {result.content}")
#
# File ~\anaconda3\envs\llms\Lib\site-packages\langchain_core\language_models\chat_models.py:368, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     356 @override
#     357 def invoke(
#     358     self,
#    (...)    363     **kwargs: Any,
#     364 ) -> BaseMessage:
#     365     config = ensure_config(config)
#     366     return cast(
#     367         "ChatGeneration",
# --> 368         self.generate_prompt(
#     369             [self._convert_input(input)],
#     370             stop=stop,
#     371             callbacks=config.get("callbacks"),
#     372             tags=config.get("tags"),
#     373             metadata=config.get("metadata"),
#     374             run_name=config.get("run_name"),
#     375             run_id=config.pop("run_id", None),
#     376             **kwargs,
#     377         ).generations[0][0],
#     378     ).message
#
# File ~\anaconda3\envs\llms\Lib\site-packages\langchain_core\language_models\chat_models.py:937, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     928 @override
#     929 def generate_prompt(
#     930     self,
#    (...)    934     **kwargs: Any,
#     935 ) -> LLMResult:
#     936     prompt_messages = [p.to_messages() for p in prompts]
# --> 937     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\anaconda3\envs\llms\Lib\site-packages\langchain_core\language_models\chat_models.py:759, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     756 for i, m in enumerate(messages):
#     757     try:
#     758         results.append(
# --> 759             self._generate_with_cache(
#     760                 m,
#     761                 stop=stop,
#     762                 run_manager=run_managers[i] if run_managers else None,
#     763                 **kwargs,
#     764             )
#     765         )
#     766     except BaseException as e:
#     767         if run_managers:
#
# File ~\anaconda3\envs\llms\Lib\site-packages\langchain_core\language_models\chat_models.py:1002, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1000     result = generate_from_stream(iter(chunks))
#    1001 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1002     result = self._generate(
#    1003         messages, stop=stop, run_manager=run_manager, **kwargs
#    1004     )
#    1005 else:
#    1006     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\anaconda3\envs\llms\Lib\site-packages\langchain_anthropic\chat_models.py:1168, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1166     return generate_from_stream(stream_iter)
#    1167 payload = self._get_request_payload(messages, stop=stop, **kwargs)
# -> 1168 data = self._client.messages.create(**payload)
#    1169 return self._format_output(data, **kwargs)
#
# File ~\anaconda3\envs\llms\Lib\site-packages\anthropic\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\llms\Lib\site-packages\anthropic\resources\messages\messages.py:953, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     946 if model in DEPRECATED_MODELS:
#     947     warnings.warn(
#     948         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     949         DeprecationWarning,
#     950         stacklevel=3,
#     951     )
# --> 953 return self._post(
#     954     "/v1/messages",
#     955     body=maybe_transform(
#     956         {
#     957             "max_tokens": max_tokens,
#     958             "messages": messages,
#     959             "model": model,
#     960             "metadata": metadata,
#     961             "stop_sequences": stop_sequences,
#     962             "stream": stream,
#     963             "system": system,
#     964             "temperature": temperature,
#     965             "thinking": thinking,
#     966             "tool_choice": tool_choice,
#     967             "tools": tools,
#     968             "top_k": top_k,
#     969             "top_p": top_p,
#     970         },
#     971         message_create_params.MessageCreateParams,
#     972     ),
#     973     options=make_request_options(
#     974         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     975     ),
#     976     cast_to=Message,
#     977     stream=stream or False,
#     978     stream_cls=Stream[RawMessageStreamEvent],
#     979 )
#
# File ~\anaconda3\envs\llms\Lib\site-packages\anthropic\_base_client.py:1336, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1322 def post(
#    1323     self,
#    1324     path: str,
#    (...)   1331     stream_cls: type[_StreamT] | None = None,
#    1332 ) -> ResponseT | _StreamT:
#    1333     opts = FinalRequestOptions.construct(
#    1334         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1335     )
# -> 1336     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\anaconda3\envs\llms\Lib\site-packages\anthropic\_base_client.py:1013, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1010 else:
#    1011     retries_taken = 0
# -> 1013 return self._request(
#    1014     cast_to=cast_to,
#    1015     options=options,
#    1016     stream=stream,
#    1017     stream_cls=stream_cls,
#    1018     retries_taken=retries_taken,
#    1019 )
#
# File ~\anaconda3\envs\llms\Lib\site-packages\anthropic\_base_client.py:1039, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1036 options = self._prepare_options(options)
#    1038 remaining_retries = options.get_max_retries(self.max_retries) - retries_taken
# -> 1039 request = self._build_request(options, retries_taken=retries_taken)
#    1040 self._prepare_request(request)
#    1042 kwargs: HttpxSendArgs = {}
#
# File ~\anaconda3\envs\llms\Lib\site-packages\anthropic\_base_client.py:487, in BaseClient._build_request(self, options, retries_taken)
#     484     else:
#     485         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 487 headers = self._build_headers(options, retries_taken=retries_taken)
#     488 params = _merge_mappings(self.default_query, options.params)
#     489 content_type = headers.get("Content-Type")
#
# File ~\anaconda3\envs\llms\Lib\site-packages\anthropic\_base_client.py:428, in BaseClient._build_headers(self, options, retries_taken)
#     418 custom_headers = options.headers or {}
#     419 headers_dict = _merge_mappings(
#     420     {
#     421         "x-stainless-timeout": str(options.timeout.read)
#    (...)    426     custom_headers,
#     427 )
# --> 428 self._validate_headers(headers_dict, custom_headers)
#     430 # headers are case-insensitive while dictionaries are not.
#     431 headers = httpx.Headers(headers_dict)
#
# File ~\anaconda3\envs\llms\Lib\site-packages\anthropic\_client.py:180, in Anthropic._validate_headers(self, headers, custom_headers)
#     177 if isinstance(custom_headers.get("Authorization"), Omit):
#     178     return
# --> 180 raise TypeError(
#     181     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     182 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"

# %%
model = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

result = model.invoke(messages)
print(f"Answer from Google: {result.content}")
# Out:
# Answer from Google: 10 times 5 is 50.

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="ollama2")
result = model.invoke(messages)
print(f"Answer from Google: {result.content}")
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[10], line 4
#       1 from langchain_ollama import ChatOllama
#       3 model = ChatOllama(model="ollama2")
# ----> 4 result = model.invoke(messages)
#       5 print(f"Answer from Google: {result.content}")
#
# File ~\anaconda3\envs\llms\Lib\site-packages\langchain_core\language_models\chat_models.py:368, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     356 @override
#     357 def invoke(
#     358     self,
#    (...)    363     **kwargs: Any,
#     364 ) -> BaseMessage:
#     365     config = ensure_config(config)
#     366     return cast(
#     367         "ChatGeneration",
# --> 368         self.generate_prompt(
#     369             [self._convert_input(input)],
#     370             stop=stop,
#     371             callbacks=config.get("callbacks"),
#     372             tags=config.get("tags"),
#     373             metadata=config.get("metadata"),
#     374             run_name=config.get("run_name"),
#     375             run_id=config.pop("run_id", None),
#     376             **kwargs,
#     377         ).generations[0][0],
#     378     ).message
#
# File ~\anaconda3\envs\llms\Lib\site-packages\langchain_core\language_models\chat_models.py:937, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     928 @override
#     929 def generate_prompt(
#     930     self,
#    (...)    934     **kwargs: Any,
#     935 ) -> LLMResult:
#     936     prompt_messages = [p.to_messages() for p in prompts]
# --> 937     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\anaconda3\envs\llms\Lib\site-packages\langchain_core\language_models\chat_models.py:759, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     756 for i, m in enumerate(messages):
#     757     try:
#     758         results.append(
# --> 759             self._generate_with_cache(
#     760                 m,
#     761                 stop=stop,
#     762                 run_manager=run_managers[i] if run_managers else None,
#     763                 **kwargs,
#     764             )
#     765         )
#     766     except BaseException as e:
#     767         if run_managers:
#
# File ~\anaconda3\envs\llms\Lib\site-packages\langchain_core\language_models\chat_models.py:1002, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1000     result = generate_from_stream(iter(chunks))
#    1001 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1002     result = self._generate(
#    1003         messages, stop=stop, run_manager=run_manager, **kwargs
#    1004     )
#    1005 else:
#    1006     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\anaconda3\envs\llms\Lib\site-packages\langchain_ollama\chat_models.py:715, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     708 def _generate(
#     709     self,
#     710     messages: list[BaseMessage],
#    (...)    713     **kwargs: Any,
#     714 ) -> ChatResult:
# --> 715     final_chunk = self._chat_stream_with_aggregation(
#     716         messages, stop, run_manager, verbose=self.verbose, **kwargs
#     717     )
#     718     generation_info = final_chunk.generation_info
#     719     chat_generation = ChatGeneration(
#     720         message=AIMessage(
#     721             content=final_chunk.text,
#    (...)    726         generation_info=generation_info,
#     727     )
#
# File ~\anaconda3\envs\llms\Lib\site-packages\langchain_ollama\chat_models.py:652, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     643 def _chat_stream_with_aggregation(
#     644     self,
#     645     messages: list[BaseMessage],
#    (...)    649     **kwargs: Any,
#     650 ) -> ChatGenerationChunk:
#     651     final_chunk = None
# --> 652     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     653         if final_chunk is None:
#     654             final_chunk = chunk
#
# File ~\anaconda3\envs\llms\Lib\site-packages\langchain_ollama\chat_models.py:737, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#     730 def _iterate_over_stream(
#     731     self,
#     732     messages: list[BaseMessage],
#     733     stop: Optional[list[str]] = None,
#     734     **kwargs: Any,
#     735 ) -> Iterator[ChatGenerationChunk]:
#     736     is_thinking = False
# --> 737     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     738         if not isinstance(stream_resp, str):
#     739             if stream_resp.get("done") is True:
#
# File ~\anaconda3\envs\llms\Lib\site-packages\langchain_ollama\chat_models.py:639, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     636 chat_params = self._chat_params(messages, stop, **kwargs)
#     638 if chat_params["stream"]:
# --> 639     yield from self._client.chat(**chat_params)
#     640 else:
#     641     yield self._client.chat(**chat_params)
#
# File ~\anaconda3\envs\llms\Lib\site-packages\ollama\_client.py:168, in Client._request.<locals>.inner()
#     166 except httpx.HTTPStatusError as e:
#     167   e.response.read()
# --> 168   raise ResponseError(e.response.text, e.response.status_code) from None
#     170 for line in r.iter_lines():
#     171   part = json.loads(line)
#
# ResponseError: model "ollama2" not found, try pulling it first (status code: 404)
