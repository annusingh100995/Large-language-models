# %%
from dotenv import load_dotenv
from langchain.prompts import ChatPromptTemplate
from langchain.schema.output_parser import StrOutputParser
from langchain.schema.runnable import RunnableLambda, RunnableParallel
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
# Load the envs var
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# %%
prompt_template = ChatPromptTemplate.from_messages(
    [
        ("system","You are a comdedian who tells jokes about {topic}"),
        ("human", "Tell me {joke_count} jokes"),
    ]
)

uppercase_output = RunnableLambda(lambda x: x.upper())
count_words = RunnableLambda(lambda x: f"Word Count: {len(x.split())}\n{x}")

chain = prompt_template | model | StrOutputParser() | uppercase_output | count_words

results = chain.invoke({"topic":"banker","joke_count":3})

print(results)
# Out:
# Word Count: 135
# ALRIGHT, ALRIGHT, SETTLE DOWN FOLKS, YOU LOOK LIKE YOU'RE WAITING FOR A LOAN TO BE APPROVED. SPEAKING OF...
#
# 1.  WHY DID THE BANKER BREAK UP WITH THE MATHEMATICIAN? BECAUSE ALL HE EVER TALKED ABOUT WAS INTEREST! GET IT? INTEREST! LIKE MONEY...AND MATH! I'LL BE HERE ALL WEEK, TRY THE VEAL!
#
# 2.  A BANKER WALKS INTO A LIBRARY AND ASKS FOR BOOKS ABOUT PARANOIA. THE LIBRARIAN WHISPERS, "THEY'RE RIGHT BEHIND YOU!" THEY'RE ALWAYS LOOKING OVER THEIR SHOULDERS, THOSE GUYS! PROBABLY COUNTING THEIR MONEY...WHICH, LET'S BE HONEST, ISN'T THEIRS ANYWAY.
#
# 3.  WHAT'S THE DIFFERENCE BETWEEN A USED CAR SALESMAN AND A BANKER? THE USED CAR SALESMAN KNOWS WHEN HE'S LYING. BA-DUM-TISH! SERIOUSLY THOUGH, HAVE YOU *SEEN* THE FINE PRINT ON THOSE LOAN AGREEMENTS? YOU NEED A LAWYER AND A MAGNIFYING GLASS JUST TO UNDERSTAND WHAT YOU'RE SIGNING!

# %% [markdown]
# ## Parallel Chains

# %%
prompt_template = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an expert product reviewer."),
        ("human", "List me main features of {product_name}"),
    ]
)

# Define pros analysis step

def analyze_pros(features):
    pros_template = ChatPromptTemplate.from_messages(
        [
            ("system","You are an expert product reviwer"),
            ("human", "Given these features : {features}, list the pros of these features")
        ]
    )
    return pros_template.format_prompt(features=features)


# Define the cons step

def analyze_cons(features):
    cons_template = ChatPromptTemplate.from_messages(
        [
            ("system","You are an expert product reviwer"),
            ("human","Given these features: {features}, list the cons of these features")
        ]
    )
    return cons_template.format_prompt(features=features)


def combine_pros_cons(pros,cons):
    return f"Pros:\n{pros}\n\nCons:\n{cons}"

# %%
pros_branch_chain = (
    RunnableLambda(lambda x: analyze_pros(x)) | model | StrOutputParser() 
)
cons_branch_chain = (
    RunnableLambda(lambda x: analyze_cons(x)) | model | StrOutputParser() 
)

chain = (
    prompt_template |
    model |
    StrOutputParser() |
    RunnableParallel(branches={"pros":pros_branch_chain, "cons":cons_branch_chain}) |
    RunnableLambda(lambda x: combine_pros_cons(x["branches"]["pros"], x["branches"]["cons"]))
)

results = chain.invoke({"product_name":"Macbook Pro"})

print(results)
# Out:
# Pros:
# Okay, based on the feature list provided, here's a breakdown of the pros of each feature category for the MacBook Pro:
#
# **Core Performance & Design:**
#
# *   **Apple Silicon Processors (M-series):**
#     *   **Pro:** Dramatically improved performance for demanding tasks like video editing, coding, and gaming.
#     *   **Pro:** Significantly better power efficiency, leading to longer battery life.
#     *   **Pro:** Runs cooler and quieter than previous Intel-based models.
# *   **Unified Memory:**
#     *   **Pro:** Faster data access and improved performance, especially for graphics-intensive applications.
#     *   **Pro:** More efficient memory management, allowing for smoother multitasking.
# *   **Liquid Retina XDR Display (on 14" and 16" models):**
#     *   **Pro:** Exceptional image quality with vibrant colors, deep blacks, and incredible brightness.
#     *   **Pro:** Ideal for content creators who need accurate color representation and high dynamic range.
#     *   **Pro:** Promotes eye comfort during extended use.
# *   **Retina Display (on 13" models):**
#     *   **Pro:** Sharp and clear visuals for everyday tasks and content consumption.
#     *   **Pro:** Accurate color reproduction for a pleasant viewing experience.
# *   **ProMotion Technology:**
#     *   **Pro:** Smoother scrolling, animations, and gameplay.
#     *   **Pro:** More responsive user interface.
#     *   **Pro:** Battery life conservation by dynamically adjusting refresh rate.
# *   **Aluminum Unibody Design:**
#     *   **Pro:** Premium look and feel.
#     *   **Pro:** Durable and resistant to damage.
#     *   **Pro:** Lightweight and portable.
# *   **macOS:**
#     *   **Pro:** User-friendly interface that's easy to learn and use.
#     *   **Pro:** Strong security features to protect your data.
#     *   **Pro:** Seamless integration with other Apple devices and services.
#     *   **Pro:** Stable and reliable operating system.
#
# **Connectivity & Expansion:**
#
# *   **Thunderbolt/USB 4 Ports:**
#     *   **Pro:** Versatile ports for connecting a wide range of peripherals and devices.
#     *   **Pro:** High-speed data transfer for quick file transfers.
#     *   **Pro:** Supports multiple external displays for increased productivity.
#     *   **Pro:** Can be used for charging the laptop.
# *   **HDMI Port (on 14" and 16" models):**
#     *   **Pro:** Convenient connection to TVs and external displays without the need for adapters.
# *   **SDXC Card Reader (on 14" and 16" models):**
#     *   **Pro:** Easy and fast transfer of photos and videos from memory cards.
#     *   **Pro:** Streamlines workflow for photographers and videographers.
# *   **MagSafe Charging:**
#     *   **Pro:** Prevents accidental damage to the laptop if the power cord is yanked.
#     *   **Pro:** Easy and convenient magnetic connection.
# *   **Wi-Fi 6E:**
#     *   **Pro:** Faster and more reliable wireless connectivity.
#     *   **Pro:** Improved performance in crowded Wi-Fi environments.
# *   **Bluetooth:**
#     *   **Pro:** Wireless connectivity for a wide range of peripherals, such as mice, keyboards, headphones and speakers.
#
# **User Experience:**
#
# *   **Backlit Magic Keyboard:**
#     *   **Pro:** Comfortable and responsive typing experience.
#     *   **Pro:** Backlighting for easy typing in low-light conditions.
# *   **Force Touch Trackpad:**
#     *   **Pro:** Precise cursor control.
#     *   **Pro:** Supports a variety of gestures for increased productivity.
# *   **1080p FaceTime HD Camera:**
#     *   **Pro:** Clear and sharp video calls.
# *   **Studio-Quality Microphones:**
#     *   **Pro:** High-quality audio recording for calls, podcasts, and voiceovers.
# *   **High-Fidelity Speaker System:**
#     *   **Pro:** Immersive audio experience with rich sound and good bass.
#     *   **Pro:** Enjoyable for music, movies, and games.
# *   **Touch Bar (on some older 13" models):**
#     *   **Pro:** Customizable controls for different applications (context-sensitive).
#     *   **Pro:** Can provide quick access to frequently used functions.
# *   **Touch ID:**
#     *   **Pro:** Secure and convenient login and authentication.
#
# **Software & Ecosystem:**
#
# *   **macOS Ecosystem:**
#     *   **Pro:** Seamless integration with other Apple devices for increased productivity.
#     *   **Pro:** Features like Handoff, Universal Clipboard, and AirDrop make it easy to work across devices.
# *   **Pre-installed Apps:**
#     *   **Pro:** Access to a suite of productivity and creative apps right out of the box.
# *   **App Store:**
#     *   **Pro:** Vast library of apps designed specifically for macOS.
# *   **Rosetta 2:**
#     *   **Pro:** Ability to run older Intel-based Mac apps on Apple Silicon.
#
# In summary, the MacBook Pro offers a compelling combination of performance, design, and user experience, making it a great choice for professionals and anyone who needs a powerful and versatile laptop. The transition to Apple Silicon has been a game-changer, delivering significant improvements in performance and battery life.
#
# Cons:
# Okay, here's a breakdown of the potential cons or downsides associated with the features listed for the MacBook Pro:
#
# **Core Performance & Design:**
#
# *   **Apple Silicon Processors (M-series):**
#     *   **Software Compatibility (Ongoing, but diminishing):** While Rosetta 2 is excellent, some very specialized or older professional software might still have compatibility issues or run less efficiently than on Intel-based Macs (though this is becoming increasingly rare).
#     *   **Limited Upgradeability:** The system-on-a-chip (SoC) design means RAM and storage are soldered to the logic board and *cannot* be upgraded after purchase.  You *must* choose the configuration you need upfront.
#     *   **Repair Restrictions:** Repairing Apple Silicon Macs can be more complex and potentially more expensive due to the integrated nature of the components.
# *   **Unified Memory:**
#     *   **Fixed Allocation:** While efficient, the unified memory pool means you can't dedicate specific amounts of RAM exclusively to the CPU or GPU, which *could* be a limitation in very specific, highly optimized workflows (though rare).
# *   **Liquid Retina XDR Display:**
#     *   **Cost:** This is a premium display technology, and it significantly adds to the overall cost of the MacBook Pro.
#     *   **Potential for Blooming:**  While minimized, mini-LED displays can exhibit some "blooming" (a halo effect around bright objects on a dark background), though Apple has done a good job of mitigating this.
# *   **Retina Display (non-XDR):**
#     *   **Lower Brightness and Contrast:** Compared to the Liquid Retina XDR display, the standard Retina display has lower peak brightness, contrast ratio, and color accuracy, making it less ideal for HDR content creation or viewing.
# *   **ProMotion Technology:**
#     *   **Perceived Flicker (Rare):** Some users are sensitive to the variable refresh rate and might perceive a slight flicker, although this is not a common complaint.
# *   **Aluminum Unibody Design:**
#     *   **Susceptibility to Dents and Scratches:** While durable, the aluminum is still prone to cosmetic damage.
#     *   **Heat Dissipation:** Aluminum can get hot under heavy workloads, although Apple Silicon is very efficient and mitigates this.
# *   **macOS:**
#     *   **Learning Curve (for Windows Users):** Users switching from Windows may experience a learning curve adapting to the macOS interface and workflow.
#     *   **Less Game Availability:** While improving, the macOS gaming ecosystem is still smaller than Windows.
#     *   **Price of Software:** Some professional macOS software can be more expensive than comparable Windows alternatives.
#
# **Connectivity & Expansion:**
#
# *   **Thunderbolt/USB 4 Ports:**
#     *   **Dongle Life (Potentially):**  While the return of HDMI and SD card slots helps, you may still need dongles/adapters for older USB-A devices or other specialized connections.
# *   **HDMI Port:**
#     *   **HDMI Version Limitations:** Some older models might have older HDMI versions that don't support the latest display resolutions and refresh rates.
# *   **SDXC Card Reader:**
#     *   **Speed Limitations:** The speed of the SD card reader may not always be the fastest available, potentially bottlenecking file transfers for very high-speed cards.
# *   **MagSafe Charging:**
#     *   **Proprietary Connector:** Requires a specific MagSafe cable, which could be an extra expense if you need a replacement.
# *   **Wi-Fi 6E:**
#     *   **Requires Wi-Fi 6E Router:** To take full advantage of Wi-Fi 6E, you need a compatible router.
# *   **Bluetooth:**
#     *   **Potential Interference:** Bluetooth can sometimes experience interference from other wireless devices.
#
# **User Experience:**
#
# *   **Backlit Magic Keyboard:**
#     *   **Key Travel Preference:** Some users may prefer keyboards with deeper key travel.
# *   **Force Touch Trackpad:**
#     *   **Learning Curve:** It takes some time to get used to the haptic feedback and pressure sensitivity.
# *   **1080p FaceTime HD Camera:**
#     *   **Still Not the Best in Class:** While good, some users still find the image quality lacking compared to dedicated webcams or smartphone cameras, especially in low light.
# *   **Studio-Quality Microphones:**
#     *   **Not a Replacement for Professional Mics:** While good for built-in microphones, they won't match the quality of dedicated studio microphones for professional recording.
# *   **Touch Bar (on some older 13" models):**
#     *   **Lack of Tactile Feedback:** Many users found the lack of physical keys frustrating and preferred traditional function keys.
#     *   **Software Dependency:** The Touch Bar's functionality relies on software support, which can be inconsistent across applications.
# *   **Touch ID:**
#     *   **Privacy Concerns:** Some users have privacy concerns about biometric data, although Apple encrypts and stores this data securely on the device.
#
# **Software & Ecosystem:**
#
# *   **macOS Ecosystem:**
#     *   **Vendor Lock-in:**  Deep integration with the Apple ecosystem can make it more difficult to switch to other platforms.
# *   **App Store:**
#     *   **App Review Process:** Apple's strict app review process can sometimes delay or prevent the release of certain apps.
# *   **Rosetta 2:**
#     *   **Performance Overhead:** Running Intel-based apps through Rosetta 2 incurs a performance penalty compared to native Apple Silicon apps.
#
# **Key Considerations:**
#
# *   **Price:** MacBook Pros are generally expensive, and the price increases significantly with higher-end configurations.
# *   **Repair Costs:** Apple repairs can be expensive, especially for complex issues.
# *   **Obsolescence:** Technology advances rapidly, and even a high-end MacBook Pro will eventually become outdated.
#
# By understanding these potential downsides, you can make a more informed decision about whether a MacBook Pro is the right choice for your needs.
